# %%
# !pip install pywin32

# %% [markdown]
# # メールの送信

# %%
import win32com.client

# %%
outlook=win32com.client.Dispatch("Outlook.Application")

# %%
mail=outlook.CreateItem(0)

mail.To="ouchi.hiroshi@persol-avct.co.jp"
mail.CC="ouchi.hiroshi@persol-avct.co.jp"
mail.BCC="ouchi.hiroshi@persol-avct.co.jp"
mail.Subject="これはTestです"
mail.Body="""これは
本文
です。"""
mail.BodyFormat=1 #1:テキスト形式、2:HTML形式
mail.Attachments.Add(r"C:\Users\salzburug\Desktop\python\windows編\セッション3Outlook\セクション3+リソース\セクション3 リソース\sample.xlsx")
# Out:
# <COMObject Add>

# %%
mail.Send()

# %%
mail.Save()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 mail.Save()
#
# File <COMObject CreateItem>:2, in Save(self)
#
# com_error: (-2147352567, '例外が発生しました。', (4096, 'Microsoft Outlook', 'このアイテムは移動または削除されています。', None, 0, -2147221238), None)
