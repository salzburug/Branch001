# %% [markdown]
# **問１．
# 『問１』フォルダ内の「メールテンプレート.xlsx」には、ある商品の販売数を社内関係者にメールで定例報告するための宛先等の情報が、「A」と「B」2種類のシートに記載されています。以下の仕様のプログラムを作成してください。**
# - シート名として「A」か「B」いずれかの文字を、商品の販売数として数値を、それぞれinput関数で入力
# - inputで指定されたシート内の各情報を用いて「report.csv」を添付したメールを作成し下書きフォルダに保存　※inputされた数値は本文内の「販売数：」部分に入力すること

# %%
# 回答欄

# %% [markdown]
# **問２．
# 任意のフォルダ内にある以下の2条件を満たす全てのメールから、全ての添付ファイルを「YYYYMMDD_メール件名_添付ファイル名」という名前で『問２』フォルダ内に保存するプログラムを作成してください。　※YYYYMMDDはプログラム実行日、添付ファイル名は拡張子付き**
# - 受信日がプログラム実行日と同じ
# - 1つ以上の添付ファイルを含む

# %%
# 回答欄

# %% [markdown]
# **問３．
# 下記の事前準備を行った後、そのフォルダ内の、件名が「アカウント情報」である全てのメールに対して、本文内の宛名・ID・パスワードをprintするプログラムを作成してください。表示形式や順番は問いません。**
#
# 【事前準備】
# 『問３』フォルダ内の「事前準備.txt」に記載されている件名と本文で、メールを計3通自分宛に送信した上で、受信トレイ配下の任意のフォルダに移動しておく　※ただし、本文内の宛名○○には任意の名字を、IDには任意の7桁の数字を、パスワードには任意の長さのアルファベットを、各メールで重複が無いように入力すること

# %%
# 回答欄
