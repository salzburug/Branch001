# %% [markdown]
# **問１．
# 『問１』フォルダ内の全ての.csvファイルを『CSV』フォルダに、ファイル名に「名簿」を含む全てのファイルを『名簿』フォルダにコピーするプログラムを作成してください。**

# %%
# 回答欄

# %% [markdown]
# **問２．
# 『問２』フォルダ内に、前レクチャーで使用した「sample.xlsx」のA列のデータをフォルダ名として、計50個のフォルダを一括作成するプログラムを作成してください。**

# %%
# 回答欄

# %% [markdown]
# **問３．
# 『問３』フォルダ内の『元データ』フォルダには、適当なファイル名が付けられた請求書Excelファイルが5つ保存されています。以下のような仕様のプログラムを作成してください。**
# - 『問３』フォルダ内に『請求書』フォルダが存在しない場合には『請求書』フォルダを新規作成する
# - 各Excelファイルのコピーを「請求書_請求先会社名_YYYYMMDD.xlsx」というファイル名で『請求書』フォルダ内に作成する　※請求先会社名はExcelファイル内から取得、YYYYMMDDにはプログラム実行日を入力

# %%
# 回答欄

# %% [markdown]
# **問４．
# 『セクション2 演習課題』フォルダ内（※配下のフォルダ内も含む）にある全ての.xlsxファイルを、ファイル名先頭に「＜○○フォルダからコピー＞」（※○○はコピー元のフォルダ名）とつけ加えた状態で『問４』フォルダ内にコピーするプログラムを作成してください。**

# %%
# 回答欄
