# %% [markdown]
# # OS

# %%
import os

# %%
os.mkdir("テスト")

# %%
os.mkdir(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\test")

# %%
os.path.exists(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\test")
# Out:
# True

# %%
os.mkdir(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\test\test2")

# %%
os.path.basename(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\sample.xlsx")
# Out:
# 'sample.xlsx'

# %%
r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\sample.xlsx".split("\\")[-1]
# Out:
# 'sample.xlsx'
