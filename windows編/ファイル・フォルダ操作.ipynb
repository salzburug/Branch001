# %% [markdown]
# # OS

# %%
import os

# %%
os.mkdir("テスト")

# %%
os.mkdir(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\test")

# %%
os.path.exists(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\test")
# Out:
# True

# %%
os.mkdir(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\test\test2")

# %%
os.path.basename(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\sample.xlsx")
# Out:
# 'sample.xlsx'

# %%
r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\sample.xlsx".split("\\")[-1]
# Out:
# 'sample.xlsx'

# %%
from glob import glob

# %%
glob(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\*")
# Out:
# ['C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample.xlsx',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample1.xlsx',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample2.xlsx',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\test',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\セクション2 演習課題',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\ファイル・フォルダ操作.ipynb']

# %%
sorted(glob(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\*"),
key=os.path.getmtime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 sorted(glob(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\*"),
# ----> 2 key=os.path.getmtime)
#
# NameError: name 'os' is not defined

# %%
import os

# %%
sorted(glob(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\*"),
key=os.path.getmtime,reverse=True)
# Out:
# ['C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\ファイル・フォルダ操作.ipynb',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\test',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\セクション2 演習課題',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample2.xlsx',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample1.xlsx',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample.xlsx']

# %%
glob(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\*.xlsx")
# Out:
# ['C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample.xlsx',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample1.xlsx',
#  'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample2.xlsx']

# %%
glob(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\sample.*")
# Out:
# ['C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample.xlsx']

# %%
import shutil

# %%
shutil move('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample1.xlsx',
            "C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト")
# Out:
#   Cell In[23], line 1
#     shutil move('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample1.xlsx',
#            ^
# SyntaxError: invalid syntax

# %%
from glob import glob

# %%
shutil move('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample1.xlsx',
            "C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト")
# Out:
#   Cell In[25], line 1
#     shutil move('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample1.xlsx',
#            ^
# SyntaxError: invalid syntax

# %%
import shutil

# %%
shutil.move('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample1.xlsx',
            "C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト")
# Out:
# 'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト\\sample1.xlsx'

# %%
shutil.copy('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample.xlsx',
            "C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト")
# Out:
# 'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト\\sample.xlsx'

# %%
shutil.copy('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample.xlsx',
            "C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト\\コピーsample.xlsx")
# Out:
# 'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト\\コピーsample.xlsx'

# %%
shutil.copytree('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\セクション2 演習課題',
            "C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト\\セクション2 演習課題")
# Out:
# 'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト\\セクション2 演習課題'

# %%
shutil.copy2('C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\sample.xlsx',
            "C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト\\コピーsample2.xlsx")
# Out:
# 'C:\\Users\\salzburug\\Desktop\\windows編\\セッション2ファイル・フォルダ操作\\テスト\\コピーsample2.xlsx'

# %%
# !pip install send2trash

# %%
from send2trash import send2trash

# %%
send2trash(r"C:\Users\salzburug\Desktop\windows編\セッション2ファイル・フォルダ操作\sample2 - コピー.xlsx")
